# %% [markdown]
# # Pipeline to prepare ligand files

# %%
prot_name = 'fxa'

# %%
DIR_LIGS = F'../../FILES/CRYSTALS/LIGS_{prot_name.upper()}'
dir_inputs = F'{DIR_LIGS}/POCKET_LIGS/'
dir_outputs_sdf = F'{DIR_LIGS}/POCKET_LIGS_PREP_SDF/'
dir_outputs_mol2 = F'{DIR_LIGS}/POCKET_LIGS_PREP_MOL2/'

# %% [markdown]
# ### First step: Output directories creation

# %%
import os
for i in [dir_outputs_mol2, dir_outputs_sdf]:
    print(i)
    if not os.path.exists(i):
        os.makedirs(i)
        print('Creating...')
# Out:
# ../../FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS_PREP_MOL2/
# ../../FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS_PREP_SDF/

# %% [markdown]
# ### Second step:
#
# ### Molecules File types
#
# <div style='background-color: #F5A566; padding: 5px 12px;'>Antes de cargar las moléculas, debemos convertirlas a un formato que sea correctamente leído con rdkit.</div>
#
# <br>
# <div class='bg-info' style='padding: 10px;'>
# Por lo que se ha analizado hasta ahora, <span style='font-weight: bold;'> desde un archivo mol2 no funcionará</span>  si la molécula tiene ciclos que no siguen el estándar de corina ('C.ar' o 'N.ar'), u oxígenos unidos a fósforo debido a que rdkit no reconoce los Oxígenos O.c2 en archivos mol2 generados por babel o Chimera (formatos distintos al estándar 'corina' que sigue rdkit).<br>El problema no parece poder resolverse sustituyendo, por ejemplo, 'C.ar' por 'C.2', pues manualmente hay que elegir qué átomos deben tener un enlace <i>sp2</i> (C=C) o sp3 (C-C) dentro del ciclo.<a src='https://sourceforge.net/p/rdkit/mailman/message/28665746/'>Fuente</a>.
# </div>
#
#
# **Para ello en necesario considerar lo siguiente:**
#
# Para usar rdkit, los archivos pueden ser leídos a partir de dos fuentes:
# 1. **`sdf` desde un pdb:** Desde un archivo pdb sin Hs, usando: `obabel -ipdb file.pdb -osdf file.sdf -p 7.4`
# 2. **`sdf` desde uel mol2:** Desde el archivo mol2 generado con `Chimera` que ya ha sido protonado con este mismo programa, usando: `obabel -imol2 file.mol2 -osdf file.sdf`. Es importante no usar el parámetro `-p`.
#
# ### Generamos los archivos .mol2 de las moléculas empleando UCSF Chimera
#
# En algunas ocasiones ha resultado más conveniente generar las moléculas con hidrógenos utilizando UCSF Chimera (al menos cuando se espera que sea a pH neutro). Para ello usar el siguiente script llamado `chim_addh.py``:
#
# ```python
# from chimera import runCommand as rc
#
# from os import chdir, listdir
# chdir("path/to/the/pdb_molecules/dir")
#
# for m in listdir('.'):
# 	rc('open ' + m)
# 	rc("addh")
# 	rc('write format mol2 0 ' + m[:-4] + '.mol2')
# 	rc('close all')
# ```
#
# Y se ejecuta con el siguiente comando desde la terminal:
#
# `chimera --nogui chim_addh.py`
#
# Nota: chimera debe estar en el path, de otro modo hay que ejecutar el script añadiendo la dirección absoluta hacia el ejecutable de chimera.

# %% [markdown]
# ### Creamos el script en el directorio actual:
# La siguiente celda crea el script mencionado arriba.

# %%
with open('chim_addh.py', 'w') as f:
    f.write(F'''
from chimera import runCommand as rc

from os import chdir, listdir
chdir("{dir_inputs}") 

for m in listdir('.'):
    rc('open ' + m)
    rc("addh")
    rc('write format mol2 0 ' + m[:-4] + '.mol2')
    rc('close all')    
    ''')

# %% [markdown]
# ### Ejecutamos el script con UCSF Chimera

# %%
# %%bash -s $dir_inputs $dir_outputs_mol2
# # Ruta al aejecutable de chimera
# chimera='/home/joel/.local/UCSF-Chimera64-1.14rc/bin/chimera'
#
# $chimera --nogui chim_addh.py
# wait
# ## Ahora movemos los archivos mol2 a la carpeta correspondiente
# mv $1/*.mol2 $2
# Out:
# Executing chim_addh.py...
# Opening 3liw_RUP_LIG.pdb...
# The following problems occurred while reading PDB file for 3liw_RUP_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3liw_RUP_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3liw_RUP_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3liw_RUP_LIG.pdb'
# Matching donors in model '3liw_RUP_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3liw_RUP_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2vvv_H21_LIG.pdb...
# The following problems occurred while reading PDB file for 2vvv_H21_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2vvv_H21_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2vvv_H21_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2vvv_H21_LIG.pdb'
# Matching donors in model '2vvv_H21_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2vvv_H21_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4y6d_48U_LIG.pdb...
# The following problems occurred while reading PDB file for 4y6d_48U_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4y6d_48U_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4y6d_48U_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4y6d_48U_LIG.pdb'
# Matching donors in model '4y6d_48U_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4y6d_48U_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2vvc_LZF_LIG.pdb...
# The following problems occurred while reading PDB file for 2vvc_LZF_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2vvc_LZF_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2vvc_LZF_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2vvc_LZF_LIG.pdb'
# Matching donors in model '2vvc_LZF_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2vvc_LZF_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1iqn_XMC_LIG.pdb...
# The following problems occurred while reading PDB file for 1iqn_XMC_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1iqn_XMC_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1iqn_XMC_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1iqn_XMC_LIG.pdb'
# Matching donors in model '1iqn_XMC_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1iqn_XMC_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1z6e_IK8_LIG.pdb...
# The following problems occurred while reading PDB file for 1z6e_IK8_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1z6e_IK8_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1z6e_IK8_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1z6e_IK8_LIG.pdb'
# Matching donors in model '1z6e_IK8_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1z6e_IK8_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4a7i_A7I_LIG.pdb...
# The following problems occurred while reading PDB file for 4a7i_A7I_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4a7i_A7I_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4a7i_A7I_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4a7i_A7I_LIG.pdb'
# Matching donors in model '4a7i_A7I_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4a7i_A7I_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2vh0_GSI_LIG.pdb...
# The following problems occurred while reading PDB file for 2vh0_GSI_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2vh0_GSI_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2vh0_GSI_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2vh0_GSI_LIG.pdb'
# Matching donors in model '2vh0_GSI_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2vh0_GSI_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2bmg_I1H_LIG.pdb...
# The following problems occurred while reading PDB file for 2bmg_I1H_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2bmg_I1H_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2bmg_I1H_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2bmg_I1H_LIG.pdb'
# Matching donors in model '2bmg_I1H_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2bmg_I1H_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1lpk_CBB_LIG.pdb...
# The following problems occurred while reading PDB file for 1lpk_CBB_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1lpk_CBB_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1lpk_CBB_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1lpk_CBB_LIG.pdb'
# Matching donors in model '1lpk_CBB_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1lpk_CBB_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4btt_VYR_LIG.pdb...
# The following problems occurred while reading PDB file for 4btt_VYR_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4btt_VYR_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4btt_VYR_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4btt_VYR_LIG.pdb'
# Matching donors in model '4btt_VYR_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4btt_VYR_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1g2l_T87_LIG.pdb...
# The following problems occurred while reading PDB file for 1g2l_T87_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1g2l_T87_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1g2l_T87_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1g2l_T87_LIG.pdb'
# Matching donors in model '1g2l_T87_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1g2l_T87_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4zha_4O5_LIG.pdb...
# The following problems occurred while reading PDB file for 4zha_4O5_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4zha_4O5_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4zha_4O5_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4zha_4O5_LIG.pdb'
# Matching donors in model '4zha_4O5_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4zha_4O5_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3cs7_LG0_LIG.pdb...
# The following problems occurred while reading PDB file for 3cs7_LG0_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3cs7_LG0_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3cs7_LG0_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3cs7_LG0_LIG.pdb'
# Matching donors in model '3cs7_LG0_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3cs7_LG0_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3kqc_LGK_LIG.pdb...
# The following problems occurred while reading PDB file for 3kqc_LGK_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3kqc_LGK_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3kqc_LGK_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3kqc_LGK_LIG.pdb'
# Matching donors in model '3kqc_LGK_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3kqc_LGK_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2w26_RIV_LIG.pdb...
# The following problems occurred while reading PDB file for 2w26_RIV_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2w26_RIV_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2w26_RIV_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2w26_RIV_LIG.pdb'
# Matching donors in model '2w26_RIV_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2w26_RIV_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 5k0h_6PK_LIG.pdb...
# The following problems occurred while reading PDB file for 5k0h_6PK_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 5k0h_6PK_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '5k0h_6PK_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '5k0h_6PK_LIG.pdb'
# Matching donors in model '5k0h_6PK_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 5k0h_6PK_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3tk5_D1Q_LIG.pdb...
# The following problems occurred while reading PDB file for 3tk5_D1Q_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3tk5_D1Q_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3tk5_D1Q_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3tk5_D1Q_LIG.pdb'
# Matching donors in model '3tk5_D1Q_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3tk5_D1Q_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2vwn_H25_LIG.pdb...
# The following problems occurred while reading PDB file for 2vwn_H25_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2vwn_H25_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2vwn_H25_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2vwn_H25_LIG.pdb'
# Matching donors in model '2vwn_H25_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2vwn_H25_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1iqj_XMH_LIG.pdb...
# The following problems occurred while reading PDB file for 1iqj_XMH_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1iqj_XMH_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1iqj_XMH_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1iqj_XMH_LIG.pdb'
# Matching donors in model '1iqj_XMH_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1iqj_XMH_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1iqf_XMD_LIG.pdb...
# The following problems occurred while reading PDB file for 1iqf_XMD_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1iqf_XMD_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1iqf_XMD_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1iqf_XMD_LIG.pdb'
# Matching donors in model '1iqf_XMD_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1iqf_XMD_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2g00_4QC_LIG.pdb...
# The following problems occurred while reading PDB file for 2g00_4QC_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2g00_4QC_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2g00_4QC_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2g00_4QC_LIG.pdb'
# Matching donors in model '2g00_4QC_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2g00_4QC_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2xbw_455_LIG.pdb...
# The following problems occurred while reading PDB file for 2xbw_455_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2xbw_455_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2xbw_455_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2xbw_455_LIG.pdb'
# Matching donors in model '2xbw_455_LIG.pdb' to acceptors
# 1 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2xbw_455_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2xbv_XBV_LIG.pdb...
# The following problems occurred while reading PDB file for 2xbv_XBV_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2xbv_XBV_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2xbv_XBV_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2xbv_XBV_LIG.pdb'
# Matching donors in model '2xbv_XBV_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2xbv_XBV_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4bti_7R9_LIG.pdb...
# The following problems occurred while reading PDB file for 4bti_7R9_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4bti_7R9_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4bti_7R9_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4bti_7R9_LIG.pdb'
# Matching donors in model '4bti_7R9_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4bti_7R9_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2y80_439_LIG.pdb...
# The following problems occurred while reading PDB file for 2y80_439_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2y80_439_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2y80_439_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2y80_439_LIG.pdb'
# Matching donors in model '2y80_439_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2y80_439_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1wu1_D91_LIG.pdb...
# The following problems occurred while reading PDB file for 1wu1_D91_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1wu1_D91_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1wu1_D91_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1wu1_D91_LIG.pdb'
# Matching donors in model '1wu1_D91_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1wu1_D91_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2phb_230_LIG.pdb...
# The following problems occurred while reading PDB file for 2phb_230_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2phb_230_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2phb_230_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2phb_230_LIG.pdb'
# Matching donors in model '2phb_230_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2phb_230_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1ksn_FXV_LIG.pdb...
# The following problems occurred while reading PDB file for 1ksn_FXV_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1ksn_FXV_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1ksn_FXV_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1ksn_FXV_LIG.pdb'
# Matching donors in model '1ksn_FXV_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1ksn_FXV_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2boh_IIA_LIG.pdb...
# The following problems occurred while reading PDB file for 2boh_IIA_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2boh_IIA_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2boh_IIA_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2boh_IIA_LIG.pdb'
# Matching donors in model '2boh_IIA_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2boh_IIA_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2bok_784_LIG.pdb...
# The following problems occurred while reading PDB file for 2bok_784_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2bok_784_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2bok_784_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2bok_784_LIG.pdb'
# Matching donors in model '2bok_784_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2bok_784_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2uwl_895_LIG.pdb...
# The following problems occurred while reading PDB file for 2uwl_895_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2uwl_895_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2uwl_895_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2uwl_895_LIG.pdb'
# Matching donors in model '2uwl_895_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2uwl_895_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2wyj_898_LIG.pdb...
# The following problems occurred while reading PDB file for 2wyj_898_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2wyj_898_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2wyj_898_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2wyj_898_LIG.pdb'
# Matching donors in model '2wyj_898_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2wyj_898_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2y7z_C0Z_LIG.pdb...
# The following problems occurred while reading PDB file for 2y7z_C0Z_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2y7z_C0Z_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2y7z_C0Z_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2y7z_C0Z_LIG.pdb'
# Matching donors in model '2y7z_C0Z_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2y7z_C0Z_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2j2u_GSQ_LIG.pdb...
# The following problems occurred while reading PDB file for 2j2u_GSQ_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2j2u_GSQ_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2j2u_GSQ_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2j2u_GSQ_LIG.pdb'
# Matching donors in model '2j2u_GSQ_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2j2u_GSQ_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1f0s_PR2_LIG.pdb...
# The following problems occurred while reading PDB file for 1f0s_PR2_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1f0s_PR2_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1f0s_PR2_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1f0s_PR2_LIG.pdb'
# Matching donors in model '1f0s_PR2_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1f0s_PR2_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2wyg_461_LIG.pdb...
# The following problems occurred while reading PDB file for 2wyg_461_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2wyg_461_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2wyg_461_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2wyg_461_LIG.pdb'
# Matching donors in model '2wyg_461_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2wyg_461_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1ioe_XMA_LIG.pdb...
# The following problems occurred while reading PDB file for 1ioe_XMA_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1ioe_XMA_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1ioe_XMA_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1ioe_XMA_LIG.pdb'
# Matching donors in model '1ioe_XMA_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1ioe_XMA_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3tk6_D46_LIG.pdb...
# The following problems occurred while reading PDB file for 3tk6_D46_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3tk6_D46_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3tk6_D46_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3tk6_D46_LIG.pdb'
# Matching donors in model '3tk6_D46_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3tk6_D46_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3kqe_LGM_LIG.pdb...
# The following problems occurred while reading PDB file for 3kqe_LGM_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3kqe_LGM_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3kqe_LGM_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3kqe_LGM_LIG.pdb'
# Matching donors in model '3kqe_LGM_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3kqe_LGM_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3k9x_MBM_LIG.pdb...
# The following problems occurred while reading PDB file for 3k9x_MBM_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3k9x_MBM_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3k9x_MBM_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3k9x_MBM_LIG.pdb'
# Matching donors in model '3k9x_MBM_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# ...
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3sw2_FI1_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2j4i_GSJ_LIG.pdb...
# The following problems occurred while reading PDB file for 2j4i_GSJ_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2j4i_GSJ_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2j4i_GSJ_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2j4i_GSJ_LIG.pdb'
# Matching donors in model '2j4i_GSJ_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2j4i_GSJ_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2uwo_701_LIG.pdb...
# The following problems occurred while reading PDB file for 2uwo_701_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2uwo_701_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2uwo_701_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2uwo_701_LIG.pdb'
# Matching donors in model '2uwo_701_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2uwo_701_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2p16_GG2_LIG.pdb...
# The following problems occurred while reading PDB file for 2p16_GG2_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2p16_GG2_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2p16_GG2_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2p16_GG2_LIG.pdb'
# Matching donors in model '2p16_GG2_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2p16_GG2_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2j38_GS5_LIG.pdb...
# The following problems occurred while reading PDB file for 2j38_GS5_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2j38_GS5_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2j38_GS5_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2j38_GS5_LIG.pdb'
# Matching donors in model '2j38_GS5_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2j38_GS5_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1iqi_XMG_LIG.pdb...
# The following problems occurred while reading PDB file for 1iqi_XMG_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1iqi_XMG_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1iqi_XMG_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1iqi_XMG_LIG.pdb'
# Matching donors in model '1iqi_XMG_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1iqi_XMG_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2p3t_993_LIG.pdb...
# The following problems occurred while reading PDB file for 2p3t_993_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2p3t_993_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2p3t_993_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2p3t_993_LIG.pdb'
# Matching donors in model '2p3t_993_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2p3t_993_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2vwo_LZG_LIG.pdb...
# The following problems occurred while reading PDB file for 2vwo_LZG_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2vwo_LZG_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2vwo_LZG_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2vwo_LZG_LIG.pdb'
# Matching donors in model '2vwo_LZG_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2vwo_LZG_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1v3x_D76_LIG.pdb...
# The following problems occurred while reading PDB file for 1v3x_D76_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1v3x_D76_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1v3x_D76_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1v3x_D76_LIG.pdb'
# Matching donors in model '1v3x_D76_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1v3x_D76_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3cen_FXA_LIG.pdb...
# The following problems occurred while reading PDB file for 3cen_FXA_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3cen_FXA_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3cen_FXA_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3cen_FXA_LIG.pdb'
# Matching donors in model '3cen_FXA_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3cen_FXA_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 3kl6_443_LIG.pdb...
# The following problems occurred while reading PDB file for 3kl6_443_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 3kl6_443_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '3kl6_443_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '3kl6_443_LIG.pdb'
# Matching donors in model '3kl6_443_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 3kl6_443_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 4btu_6XS_LIG.pdb...
# The following problems occurred while reading PDB file for 4btu_6XS_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 4btu_6XS_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '4btu_6XS_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '4btu_6XS_LIG.pdb'
# Matching donors in model '4btu_6XS_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 4btu_6XS_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 1mq6_XLD_LIG.pdb...
# The following problems occurred while reading PDB file for 1mq6_XLD_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 1mq6_XLD_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '1mq6_XLD_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '1mq6_XLD_LIG.pdb'
# Matching donors in model '1mq6_XLD_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 1mq6_XLD_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Opening 2p3u_663_LIG.pdb...
# The following problems occurred while reading PDB file for 2p3u_663_LIG.pdb
# warning:  Ignored bad PDB record found on line 1
#
# 2p3u_663_LIG.pdb opened
# Chain-initial residues that are actual N terminii:
#
# Chain-initial residues that are not actual N terminii:
#
# Chain-final residues that are actual C terminii:
#
# Chain-final residues that are not actual C terminii:
#
# Categorizing heavy atoms
# Building search tree of atom positions
# Adding simple fixed hydrogens
# Adding co-planar hydrogens
# Finding hydrogen bonds
# Finding acceptors in model '2p3u_663_LIG.pdb'
# Building search tree of acceptor atoms
# Finding donors in model '2p3u_663_LIG.pdb'
# Matching donors in model '2p3u_663_LIG.pdb' to acceptors
# 0 hydrogen bonds
#
# Sorting hydrogen bonds by distance
# Organizing h-bond info
# Adding hydrogens by h-bond strength
# Adding hydrogens to primary aromatic amines
# Using steric criteria to resolve partial h-bonders
# Adding hydrogens to non-h-bonding atoms
# Deciding aromatic nitrogen protonation
# Hydrogens added
# Hydrogens added
#
# Wrote 2p3u_663_LIG.mol2 into /home/joel/Documentos/Doctorado/DOCTO_TESIS/Proteinas_Modelo/CDK2/FXa/FILES/CRYSTALS/LIGS_FXA/POCKET_LIGS
# Executed chim_addh.py
# Cannot find consistent set of bond orders for ring system containing atom #0:1.B@C48
# Cannot find consistent set of bond orders for ring system containing atom #0:301.A@C26
# Cannot find consistent set of bond orders for ring system containing atom #0:301.A@C21

# %% [markdown]
# Como resultado tendríamos las moléculas mol2 en su carpeta correspondiente. el siguiente paso es usar babel, para generar los archivos *sdf*.

# %% [markdown]
# ### Usamos OpenBabel para generar los archivos sdf (para usar con rdkit)
#
#
# Los archivos pueden ser leídos a partir de dos fuentes:
# 1. **`sdf` desde un pdb:** Desde un archivo pdb sin Hs, usando: `obabel -ipdb file.pdb -osdf file.sdf -p 7.4`
# 2. **`sdf` desde uel mol2:** Desde el archivo mol2 generado con `Chimera` que ya ha sido protonado con este mismo programa, usando: `obabel -imol2 file.mol2 -osdf file.sdf`. Es importante no usar el parámetro `-p`
#
# ```bash
# # Usamos obabel
# cd "../ARCHIVOS/CRISTALES/LIGS_CDK2/IN_POCKET_NON_PREP"
# for mol in `ls *pdb`
# do
#     name=${mol%.*}
#     # Directamente desde el archivo pdb sin Hs
#     obabel -ipdb $mol -osdf -O ${name}_from_pdb.sdf -p 7.4 # Añade Hs a ph fisiológico
# done
#
# mv *sdf ../LIGS_POSES_SDF/
#
# cd "../LIGS_PREP_IN_POCKET"
# for mol in `ls *mol2`
# do
#     name=${mol%.*}
#     # directamente desde el archivo mol2 generado con chimera y sin el parámetro -p
#     obabel -imol2 $mol -osdf -O ${name}_from_mol2.sdf
# done
#
# mv *sdf ../LIGS_POSES_SDF/
# ```

# %% [markdown]
# ### Ejecutamos obabel

# %%
mol2_dir = dir_outputs_mol2.split('/')[-2]
sdf_dir = dir_outputs_sdf.split('/')[-2]

# %%
# %%bash -s $dir_inputs $sdf_dir $mol2_dir
# cd $1
# for mol in `ls *pdb`
# do
#     name=${mol%.*}
#     # Directamente desde el archivo pdb sin Hs
#     obabel -ipdb $mol -osdf -O ${name}_from_pdb.sdf -p 7.4 # Añade Hs a ph fisiológico
# done
# # Mueve los archivos al directorio de sdfs
# mv *.sdf ../$2
#
# # Nos movemos al directorio con archivos mol2
# cd ../$3
# for mol in `ls *mol2`
# do
#     name=${mol%.*}
#     # directamente desde el archivo mol2 generado con chimera y sin el parámetro -p
#     obabel -imol2 $mol -osdf -O ${name}_from_mol2.sdf
# done
# # Mueve los archivos al directorio de sdfs
# mv *.sdf ../$2
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted

# %% [markdown]
# Cuando la molécula provenga desde un archivo *pdbqt* o *pdb* de docking, el proceso para obtener los archivos superiores es primero remover los hidrógenos de la molécula y luego añadirlos con `Chimera` o `babel` (en teoría, antes del docking se habría hecho el mismo proceso para tener el estado de protonación correcto). Finalemente se guardará la molécula en un archivo **`mol2`** que correspoonde al solicitado en el punto #1 de la lista anterior.

# %% [markdown]
# ## ¡Terminado!
# El análisis continúa en el notbooks de cálculo de descriptores con *rdkit*.
